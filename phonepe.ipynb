# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install psycopg2
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install plotly.express
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install nbformat --upgrade
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import json
import os
import psycopg2

from sqlalchemy import create_engine
engine = create_engine('postgresql+psycopg2://postgres:1005@localhost/phonepay')

import plotly.express as px

import matplotlib.pyplot as plt

# %%
path="C:/GD/Notes/DS Class/DTM15/Project/Phonepay project/github/pulse/data/aggregated/transaction/country/india/state/"
state_list=os.listdir(path)

AT_clm={'States':[], 'Years':[],'Quater':[],'Transaction_type':[], 'Transaction_count':[], 'Transaction_amount':[]}

for state in state_list:
    p_s=path+state+"/"
    years_list=os.listdir(p_s)
    for year in years_list:
        p_y=p_s+year+"/"
        quater_list=os.listdir(p_y)
        for quater in quater_list:
            p_q=p_y+quater
            Data=open(p_q,'r')
            D=json.load(Data)
            for i in D['data']['transactionData']:
              Name=i['name']
              count=i['paymentInstruments'][0]['count']
              amount=i['paymentInstruments'][0]['amount']
              AT_clm['Transaction_type'].append(Name)
              AT_clm['Transaction_count'].append(count)
              AT_clm['Transaction_amount'].append(amount)
              AT_clm['States'].append(state)
              AT_clm['Years'].append(year)
              AT_clm['Quater'].append(int(quater.strip('.json')))

agg_trans=pd.DataFrame(AT_clm)

agg_trans['States']=agg_trans['States'].str.replace('andaman-&-nicobar-islands','andaman & nicobar')
agg_trans['States']=agg_trans['States'].str.replace('jammu-&-kashmir', 'jammu & kashmir')
agg_trans['States']=agg_trans['States'].str.replace('dadra-&-nagar-haveli-&-daman-&-diu','dadra and nagar haveli and daman and diu')
agg_trans['States']=agg_trans['States'].str.replace("-"," ")
agg_trans['States']=agg_trans['States'].str.title()

# %%
agg_trans
# Out:
#                  States Years  Quater          Transaction_type  \
# 0     Andaman & Nicobar  2018       1  Recharge & bill payments
# 1     Andaman & Nicobar  2018       1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018       1         Merchant payments
# 3     Andaman & Nicobar  2018       1        Financial Services
# 4     Andaman & Nicobar  2018       1                    Others
# ...                 ...   ...     ...                       ...
# 4309        West Bengal  2023       4         Merchant payments
# 4310        West Bengal  2023       4     Peer-to-peer payments
# 4311        West Bengal  2023       4  Recharge & bill payments
# 4312        West Bengal  2023       4        Financial Services
# 4313        West Bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# ...

# %%
#2 aggregated/user
path="C:/GD/Notes/DS Class/DTM15/Project/Phonepay project/github/pulse/data/aggregated/user/country/india/state/"
state_list=os.listdir(path)

AU_clm={'States':[], 'Years':[],'Quater':[],'Brands':[], 'Reg_user_count':[], 'Reg_percentage':[]}

for state in state_list:
    p_s=path+state+"/"
    years_list=os.listdir(p_s)
    for year in years_list:
        p_y=p_s+year+"/"
        quater_list=os.listdir(p_y)
        for quater in quater_list:
            p_q=p_y+quater
            Data=open(p_q,'r')
            D=json.load(Data)
            try:
                for i in D['data']['usersByDevice']:
                    Brand=i['brand']
                    count=i['count']
                    percentage=i['percentage']
                    AU_clm['Brands'].append(Brand)
                    AU_clm['Reg_user_count'].append(count)
                    AU_clm['Reg_percentage'].append(percentage)
                    AU_clm['States'].append(state)
                    AU_clm['Years'].append(year)
                    AU_clm['Quater'].append(int(quater.strip('.json')))
            except:
                pass

agg_users=pd.DataFrame(AU_clm)

agg_users['States']=agg_users['States'].str.replace('andaman-&-nicobar-islands','andaman & nicobar')
agg_users['States']=agg_users['States'].str.replace('jammu-&-kashmir', 'jammu & kashmir')
agg_users['States']=agg_users['States'].str.replace('dadra-&-nagar-haveli-&-daman-&-diu','dadra and nagar haveli and daman and diu')
agg_users['States']=agg_users['States'].str.replace("-"," ")
agg_users['States']=agg_users['States'].str.title()

# %%
agg_users
# Out:
#                  States Years  Quater   Brands  Reg_user_count  Reg_percentage
# 0     Andaman & Nicobar  2018       1   Xiaomi            1665        0.247033
# 1     Andaman & Nicobar  2018       1  Samsung            1445        0.214392
# 2     Andaman & Nicobar  2018       1     Vivo             982        0.145697
# 3     Andaman & Nicobar  2018       1     Oppo             501        0.074332
# 4     Andaman & Nicobar  2018       1  OnePlus             332        0.049258
# ...                 ...   ...     ...      ...             ...             ...
# 6727        West Bengal  2022       1   Lenovo          330017        0.015056
# 6728        West Bengal  2022       1  Infinix          284678        0.012987
# 6729        West Bengal  2022       1     Asus          280347        0.012790
# 6730        West Bengal  2022       1    Apple          277752        0.012671
# 6731        West Bengal  2022       1   Others         2196334        0.100199
#
# [6732 rows x 6 columns]

# %%
#3 map/transaction
path="C:/GD/Notes/DS Class/DTM15/Project/Phonepay project/github/pulse/data/map/transaction/hover/country/india/state/"
state_list=os.listdir(path)


MT_clm={'States':[], 'Years':[],'Quater':[],'District_name':[], 'Transaction_count':[], 'Transaction_amount':[]}

for state in state_list:
    p_s=path+state+"/"
    years_list=os.listdir(p_s)
    for year in years_list:
        p_y=p_s+year+"/"
        quater_list=os.listdir(p_y)
        for quater in quater_list:
            p_q=p_y+quater
            Data=open(p_q,'r')
            D=json.load(Data)
            try:
              for i in D['data']['hoverDataList']:
                Name=i['name']
                count=i['metric'][0]['count']
                amount=i['metric'][0]['amount']
                MT_clm['District_name'].append(Name)
                MT_clm['Transaction_count'].append(count)
                MT_clm['Transaction_amount'].append(amount)
                MT_clm['States'].append(state)
                MT_clm['Years'].append(year)
                MT_clm['Quater'].append(int(quater.strip('.json')))
            except Exception as e:
              print(f"Error processing file '{p_q}': {e}")

map_trans=pd.DataFrame(MT_clm)

map_trans['States']=map_trans['States'].str.replace('andaman-&-nicobar-islands','andaman & nicobar')
map_trans['States']=map_trans['States'].str.replace('jammu-&-kashmir', 'jammu & kashmir')
map_trans['States']=map_trans['States'].str.replace('dadra-&-nagar-haveli-&-daman-&-diu','dadra and nagar haveli and daman and diu')
map_trans['States']=map_trans['States'].str.replace("-"," ")
map_trans['States']=map_trans['States'].str.title()

# %%
map_trans
# Out:
#                   States Years  Quater                      District_name  \
# 0      Andaman & Nicobar  2018       1  north and middle andaman district
# 1      Andaman & Nicobar  2018       1             south andaman district
# 2      Andaman & Nicobar  2018       1                  nicobars district
# 3      Andaman & Nicobar  2018       2  north and middle andaman district
# 4      Andaman & Nicobar  2018       2             south andaman district
# ...                  ...   ...     ...                                ...
# 17559        West Bengal  2023       4                     nadia district
# 17560        West Bengal  2023       4                   birbhum district
# 17561        West Bengal  2023       4           purba medinipur district
# 17562        West Bengal  2023       4                    maldah district
# 17563        West Bengal  2023       4                 darjiling district
#
#        Transaction_count  Transaction_amount
# ...

# %%
#4 map/User
path="C:/GD/Notes/DS Class/DTM15/Project/Phonepay project/github/pulse/data/map/user/hover/country/india/state/"
state_list=os.listdir(path)

MU_clm={'States':[], 'Years':[],'Quater':[],'District_name':[], 'Reg_users':[], 'App_opens':[]}

for state in state_list:
    p_s=path+state+"/"
    years_list=os.listdir(p_s)
    for year in years_list:
        p_y=p_s+year+"/"
        quater_list=os.listdir(p_y)
        for quater in quater_list:
            p_q=p_y+quater
            Data=open(p_q,'r')
            D=json.load(Data)
            for i in D['data']['hoverData'].items():
              district=i[0]
              regusers=i[1]['registeredUsers']
              appopens=i[1]['appOpens']
              MU_clm['District_name'].append(district)
              MU_clm['Reg_users'].append(regusers)
              MU_clm['App_opens'].append(appopens)
              MU_clm['States'].append(state)
              MU_clm['Years'].append(year)
              MU_clm['Quater'].append(int(quater.strip('.json')))

map_users=pd.DataFrame(MU_clm)

map_users['States']=map_users['States'].str.replace('andaman-&-nicobar-islands','andaman & nicobar')
map_users['States']=map_users['States'].str.replace('jammu-&-kashmir', 'jammu & kashmir')
map_users['States']=map_users['States'].str.replace('dadra-&-nagar-haveli-&-daman-&-diu','dadra and nagar haveli and daman and diu')
map_users['States']=map_users['States'].str.replace("-"," ")
map_users['States']=map_users['States'].str.title()

# %%
map_users
# Out:
#                   States Years  Quater                      District_name  \
# 0      Andaman & Nicobar  2018       1  north and middle andaman district
# 1      Andaman & Nicobar  2018       1             south andaman district
# 2      Andaman & Nicobar  2018       1                  nicobars district
# 3      Andaman & Nicobar  2018       2  north and middle andaman district
# 4      Andaman & Nicobar  2018       2             south andaman district
# ...                  ...   ...     ...                                ...
# 17563        West Bengal  2023       4                     nadia district
# 17564        West Bengal  2023       4                   birbhum district
# 17565        West Bengal  2023       4           purba medinipur district
# 17566        West Bengal  2023       4                    maldah district
# 17567        West Bengal  2023       4                 darjiling district
#
#        Reg_users  App_opens
# 0            632          0
# ...

# %%
#5 Top transaction
path="C:/GD/Notes/DS Class/DTM15/Project/Phonepay project/github/pulse/data/top/transaction/country/india/state/"
state_list=os.listdir(path)


TT_clm={'States':[], 'Years':[],'Quater':[],'Pincodes':[], 'Transaction_count':[], 'Transaction_amount':[]}

for state in state_list:
    p_s=path+state+"/"
    years_list=os.listdir(p_s)
    for year in years_list:
        p_y=p_s+year+"/"
        quater_list=os.listdir(p_y)
        for quater in quater_list:
            p_q=p_y+quater
            Data=open(p_q,'r')
            D=json.load(Data)
            for i in D['data']['pincodes']:
                Entity_name=i['entityName']
                count=i['metric']['count']
                amount=i['metric']['amount']
                TT_clm['Pincodes'].append(Entity_name)
                TT_clm['Transaction_count'].append(count)
                TT_clm['Transaction_amount'].append(amount)
                TT_clm['States'].append(state)
                TT_clm['Years'].append(year)
                TT_clm['Quater'].append(int(quater.strip('.json')))

top_trans=pd.DataFrame(TT_clm)

top_trans['States']=top_trans['States'].str.replace('andaman-&-nicobar-islands','andaman & nicobar')
top_trans['States']=top_trans['States'].str.replace('jammu-&-kashmir', 'jammu & kashmir')
top_trans['States']=top_trans['States'].str.replace('dadra-&-nagar-haveli-&-daman-&-diu','dadra and nagar haveli and daman and diu')
top_trans['States']=top_trans['States'].str.replace("-"," ")
top_trans['States']=top_trans['States'].str.title()

# %%
top_trans['Pincodes']
# Out:
# 0       744101
# 1       744103
# 2       744102
# 3       744105
# 4       744104
#          ...
# 8562    721301
# 8563    700001
# 8564    732125
# 8565    700039
# 8566    700014
# Name: Pincodes, Length: 8567, dtype: object

# %%
#6 top/user
path="C:/GD/Notes/DS Class/DTM15/Project/Phonepay project/github/pulse/data/top/user/country/india/state/"
state_list=os.listdir(path)


TU_clm={'States':[], 'Years':[],'Quater':[],'Pincodes': [], 'Reg_users':[]}

for state in state_list:
    p_s=path+state+"/"
    years_list=os.listdir(p_s)
    for year in years_list:
        p_y=p_s+year+"/"
        quater_list=os.listdir(p_y)
        for quater in quater_list:
            p_q=p_y+quater
            Data=open(p_q,'r')
            D=json.load(Data)
            for i in D['data']['pincodes']:
                Name=i['name']
                reg_users=i['registeredUsers']
                TU_clm['Pincodes'].append(Name)
                TU_clm['Reg_users'].append(reg_users)
                TU_clm['States'].append(state)
                TU_clm['Years'].append(year)
                TU_clm['Quater'].append(int(quater.strip('.json')))

top_user=pd.DataFrame(TU_clm)

top_user['States']=top_user['States'].str.replace('andaman-&-nicobar-islands','andaman & nicobar')
top_user['States']=top_user['States'].str.replace('jammu-&-kashmir', 'jammu & kashmir')
top_user['States']=top_user['States'].str.replace('dadra-&-nagar-haveli-&-daman-&-diu','dadra and nagar haveli and daman and diu')
top_user['States']=top_user['States'].str.replace("-"," ")
top_user['States']=top_user['States'].str.title()

# %%
top_user
# Out:
#                  States Years  Quater Pincodes  Reg_users
# 0     Andaman & Nicobar  2018       1   744103       1608
# 1     Andaman & Nicobar  2018       1   744101       1108
# 2     Andaman & Nicobar  2018       1   744105       1075
# 3     Andaman & Nicobar  2018       1   744102       1006
# 4     Andaman & Nicobar  2018       1   744104        272
# ...                 ...   ...     ...      ...        ...
# 8563        West Bengal  2023       4   700015     126663
# 8564        West Bengal  2023       4   742304     123320
# 8565        West Bengal  2023       4   721101     123088
# 8566        West Bengal  2023       4   700150     119283
# 8567        West Bengal  2023       4   700091     118578
#
# [8568 rows x 5 columns]

# %%
agg_trans.to_sql('agg_trans', engine, if_exists='replace', index=False)
agg_users.to_sql('agg_users', engine, if_exists='replace', index=False)
map_trans.to_sql('map_trans', engine, if_exists='replace', index=False)
map_users.to_sql('map_users', engine, if_exists='replace', index=False)
top_trans.to_sql('top_trans', engine, if_exists='replace', index=False)
top_user.to_sql('top_user', engine, if_exists='replace', index=False)
# Out:
# 568

# %%
agg_trans_df = pd.read_sql('agg_trans', engine)
agg_trans_df
# Out:
#                  States Years  Quater          Transaction_type  \
# 0     Andaman & Nicobar  2018       1  Recharge & bill payments
# 1     Andaman & Nicobar  2018       1     Peer-to-peer payments
# 2     Andaman & Nicobar  2018       1         Merchant payments
# 3     Andaman & Nicobar  2018       1        Financial Services
# 4     Andaman & Nicobar  2018       1                    Others
# ...                 ...   ...     ...                       ...
# 4309        West Bengal  2023       4         Merchant payments
# 4310        West Bengal  2023       4     Peer-to-peer payments
# 4311        West Bengal  2023       4  Recharge & bill payments
# 4312        West Bengal  2023       4        Financial Services
# 4313        West Bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 0                  4200        1.845307e+06
# 1                  1871        1.213866e+07
# 2                   298        4.525072e+05
# ...

# %%
agg_trans_df[agg_trans_df["Years"]=='2021']
# Out:
#                  States Years  Quater          Transaction_type  \
# 60    Andaman & Nicobar  2021       1     Peer-to-peer payments
# 61    Andaman & Nicobar  2021       1  Recharge & bill payments
# 62    Andaman & Nicobar  2021       1         Merchant payments
# 63    Andaman & Nicobar  2021       1        Financial Services
# 64    Andaman & Nicobar  2021       1                    Others
# ...                 ...   ...     ...                       ...
# 4269        West Bengal  2021       4     Peer-to-peer payments
# 4270        West Bengal  2021       4         Merchant payments
# 4271        West Bengal  2021       4  Recharge & bill payments
# 4272        West Bengal  2021       4        Financial Services
# 4273        West Bengal  2021       4                    Others
#
#       Transaction_count  Transaction_amount
# 60               105458        6.653914e+08
# 61                84119        3.716092e+07
# 62                53090        7.860698e+07
# ...

# %%
ATS = agg_trans_df[agg_trans_df["Years"]=='2021']

ATS_M = ATS.groupby('States')[['Transaction_count', 'Transaction_amount']].sum()
ATS_M.reset_index(inplace = True)

# %%
fig = px.bar(ATS_M, x='States', y='Transaction_count', title='Transaction Count by State over Years')
fig.update_layout(xaxis_title='States', yaxis_title='Transaction Count')
fig.show()

# %%
ATY = agg_trans_df.groupby(['Years','States'])[['Transaction_count', 'Transaction_amount']].sum()
ATY.reset_index(inplace = True)
ATY
# Out:
#     Years             States  Transaction_count  Transaction_amount
# 0    2018  Andaman & Nicobar              58021        1.890761e+08
# 1    2018     Andhra Pradesh           77779112        1.220720e+11
# 2    2018  Arunachal Pradesh             435229        1.127124e+09
# 3    2018              Assam            8806777        1.320755e+10
# 4    2018              Bihar           44556885        6.808569e+10
# ..    ...                ...                ...                 ...
# 211  2023          Telangana         7001630531        1.105735e+13
# 212  2023            Tripura           34297902        5.927653e+10
# 213  2023      Uttar Pradesh         5135296152        7.592748e+12
# 214  2023        Uttarakhand          406500016        5.180986e+11
# 215  2023        West Bengal         2374642459        4.227142e+12
#
# [216 rows x 4 columns]

# %%
fig = px.bar(ATY, x='States', y='Transaction_count', animation_frame= 'Years',
             title='Transaction Count by State over Years')
fig.update_layout(xaxis_title='States', yaxis_title='Transaction Count', yaxis_range = [0, agg_trans_df['Transaction_count'].max() + (0.05 * agg_trans_df['Transaction_count'].max())])
fig.show()

# %%
fig = px.line(agg_trans_df, x='Years', y='Transaction_amount', color='Transaction_type', line_group='States',
              labels={'Transaction_amount': 'Transaction Amount', 'Years': 'Years', 'Transaction_type': 'Transaction Type'},
              title='Transaction Trends Over Time')
fig.show()

# %%
df_agg = agg_trans_df.groupby('Years')['Transaction_count'].sum().reset_index()

# Plotly Express line chart
fig = px.line(df_agg, x='Years', y='Transaction_count', 
              title='Transaction Count Trends Over Time', 
              labels={'Years': 'Years', 'Transaction_count': 'Total Transaction Count'})

fig.show()

# %%
df_agg = agg_trans_df.groupby(['Years', 'States'])['Transaction_count'].sum().reset_index()

# Plotly Express line chart
fig = px.line(df_agg, x='Years', y='Transaction_count', color='States',
              title='Transaction Count Trends Over Time by State', 
              labels={'Years': 'Years', 'Transaction_count': 'Total Transaction Count'})

fig.show()

# %%
fig = px.bar(agg_trans_df, x='States', y='Transaction_count', color='Years', facet_col='Years',
             title='Transaction Count by State over Years')
fig.update_layout(xaxis_title='States', yaxis_title='Transaction Count')
fig.show()

# %%
tn_df = agg_trans_df[agg_trans_df['States'] == 'Tamil Nadu']

# Plot the data
fig = px.bar(tn_df, x='Years', y='Transaction_count', color='Transaction_type',
             title='Transaction Count in Tamil Nadu by Year')
fig.update_layout(xaxis_title='Years', yaxis_title='Transaction Count')
fig.show()

# %%
tn_df = agg_trans_df[agg_trans_df['States'] == 'Tamil Nadu']

# Plot the data using a scatter plot
fig = px.scatter(tn_df, x='Transaction_count', y='Transaction_amount', color='Years',
                 size='Transaction_amount', hover_name='Years',
                 title='Transaction Count vs Transaction Amount in Tamil Nadu by Year')
fig.update_layout(xaxis_title='Transaction Count', yaxis_title='Transaction Amount')
fig.show()

# %%
fig = px.scatter(agg_trans_df, x='Transaction_count', y='Transaction_amount', color='Transaction_type',
                 title='Transaction Count vs Transaction Amount by Transaction Type')
fig.update_layout(xaxis_title='Transaction Count', yaxis_title='Transaction Amount')
fig.show()

# %%
fig = px.scatter(agg_trans_df, x='Transaction_count', y='Transaction_amount', color='Transaction_type',
                 facet_col='Years', facet_col_wrap=3, size='Transaction_amount',
                 title='Transaction Count vs Transaction Amount by Transaction Type and Year')
fig.update_layout(xaxis_title='Transaction Count', yaxis_title='Transaction Amount')
fig.show()

# %%
agg_year_type = agg_trans_df.groupby(['Years', 'Transaction_type']).sum().reset_index()

# Plot the data using a sunburst chart
fig = px.sunburst(agg_year_type, path=['Years', 'Transaction_type'], values='Transaction_count',
                  title='Transaction Count Sunburst Chart by Year and Transaction Type')
fig.show()

# %%
fig = px.scatter(agg_trans_df, x='Transaction_count', y='Transaction_amount', color='Transaction_type',
                 facet_col='Years', facet_row='Quater', facet_col_wrap=3,
                 title='Transaction Count vs Transaction Amount by Transaction Type, Year, and Quarter')
fig.update_layout(xaxis_title='Transaction Count', yaxis_title='Transaction Amount')
fig.show()

# %%
fig3 = px.scatter(agg_trans_df, x='Transaction_count', y='Transaction_amount', animation_frame='Years',
                  title='Transaction Count vs Transaction Amount by Year')
fig3.show()

# %%
import pandas as pd
import plotly.graph_objs as go
import plotly.express as px

# Assuming agg_trans_df is already loaded

# Bar chart for transaction count by state
state_transaction_count = agg_trans_df.groupby('States')['Transaction_count'].sum().reset_index()
fig1 = px.bar(state_transaction_count, x='States', y='Transaction_count', title='Total Transaction Count by State')

# Pie chart for transaction amount by transaction type
transaction_amount_by_type = agg_trans_df.groupby('Transaction_type')['Transaction_amount'].sum().reset_index()
fig2 = px.pie(transaction_amount_by_type, values='Transaction_amount', names='Transaction_type',
              title='Total Transaction Amount by Transaction Type')

# Scatter plot for transaction count vs transaction amount
fig3 = px.scatter(agg_trans_df, x='Transaction_count', y='Transaction_amount', color='Years',
                  title='Transaction Count vs Transaction Amount by Year')

# Sunburst chart for transaction count by year, quarter, and transaction type
fig4 = px.sunburst(agg_trans_df, path=['Years', 'Quater', 'Transaction_type'], values='Transaction_count',
                   title='Transaction Count Sunburst Chart by Year, Quarter, and Transaction Type')

# Display the charts
fig1.show()
fig2.show()
fig3.show()
fig4.show()

# %%
agg_trans_df["Years"].unique()
# Out:
# array(['2018', '2019', '2020', '2021', '2022', '2023'], dtype=object)

# %%
ATS = agg_trans_df[agg_trans_df["Years"]=='2021']

ATS_M = ATS.groupby('States')[['Transaction_count', 'Transaction_amount']].sum()
ATS_M.reset_index(inplace = True)

fig = px.choropleth(
    ATS_M,
    geojson="https://gist.githubusercontent.com/jbrobst/56c13bbbf9d97d187fea01ca62ea5112/raw/e388c4cae20aa53cb5090210a42ebb9b765c0a36/india_states.geojson",
    featureidkey='properties.ST_NM',
    locations='States',
    color='Transaction_count',
    color_continuous_scale='turbo',
    range_color = (ATS_M['Transaction_count'].min(), ATS_M['Transaction_count'].max()),
    title = 'Transacion count'
    )

fig.update_geos(fitbounds="locations", visible=False)

fig.show()

# %%
agg_trans_df.query(' States == "Tamil Nadu" and Years == "2023" and Quater == 1 and Transaction_type == "Merchant payments" ')
# Out:
#           States Years  Quater   Transaction_type  Transaction_count  \
# 3694  Tamil Nadu  2023       1  Merchant payments          248540772
#
#       Transaction_amount
# 3694        1.242503e+11

# %%
fig = px.sunburst(agg_trans_df, path=['Transaction_type', 'Years'], values='Transaction_count')

# %%
map_trans.columns
# Out:
# Index(['States', 'Years', 'Quater', 'District_name', 'Transaction_count',
#        'Transaction_amount'],
#       dtype='object')

# %%
fig = px.scatter(agg_trans_df, x='States', y='Transaction_amount',color='Transaction_type',animation_frame="Years", range_y=[0, 1800000000])
fig.show()

# %%
agg_trans_df.query('Years == "2023"')
# Out:
#                  States Years  Quater          Transaction_type  \
# 100   Andaman & Nicobar  2023       1         Merchant payments
# 101   Andaman & Nicobar  2023       1     Peer-to-peer payments
# 102   Andaman & Nicobar  2023       1  Recharge & bill payments
# 103   Andaman & Nicobar  2023       1        Financial Services
# 104   Andaman & Nicobar  2023       1                    Others
# ...                 ...   ...     ...                       ...
# 4309        West Bengal  2023       4         Merchant payments
# 4310        West Bengal  2023       4     Peer-to-peer payments
# 4311        West Bengal  2023       4  Recharge & bill payments
# 4312        West Bengal  2023       4        Financial Services
# 4313        West Bengal  2023       4                    Others
#
#       Transaction_count  Transaction_amount
# 100             1122063        1.008822e+09
# 101              862347        3.299762e+09
# 102              286024        1.463385e+08
# ...

# %%
agg_trans_df = pd.read_sql('agg_trans', engine)

states = agg_trans_df['States'].unique()
states
# Out:
# array(['Andaman & Nicobar', 'Andhra Pradesh', 'Arunachal Pradesh',
#        'Assam', 'Bihar', 'Chandigarh', 'Chhattisgarh',
#        'Dadra And Nagar Haveli And Daman And Diu', 'Delhi', 'Goa',
#        'Gujarat', 'Haryana', 'Himachal Pradesh', 'Jammu & Kashmir',
#        'Jharkhand', 'Karnataka', 'Kerala', 'Ladakh', 'Lakshadweep',
#        'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya', 'Mizoram',
#        'Nagaland', 'Odisha', 'Puducherry', 'Punjab', 'Rajasthan',
#        'Sikkim', 'Tamil Nadu', 'Telangana', 'Tripura', 'Uttar Pradesh',
#        'Uttarakhand', 'West Bengal'], dtype=object)

# %%
coloum1 = 'States'
coloum2 = [col for col in agg_trans_df.columns if col not in coloum1]
coloum2
# Out:
# ['Years',
#  'Quater',
#  'Transaction_type',
#  'Transaction_count',
#  'Transaction_amount']

# %%
map_trans_df = pd.read_sql('map_trans', engine)

# %%
MTS_M = map_trans_df.query('States == "Tamil Nadu" and Years == "2023" and Quater == 1')

# %%
map_trans_df.groupby(['States',	'Years', 'District_name'])

# %%
#MTS_quarter = MTS_M[MTS_M['Quater'] == selected_quarter]

fig = px.bar(MTS_M, y='District_name', x=['Transaction_count'], 
             barmode='stack', orientation='h', 
             title=f'Transaction Count and Amount by District for Quarter {1}',
             labels={'value': 'Transaction', 'variable': 'Type'})

# Update layout
fig.update_layout(xaxis_title='Transaction', yaxis_title='Districts', legend_title='Type')

# Show the figure
fig.show()

# %%
MT_D_M = map_trans_df.query('States == "Tamil Nadu" and Years == "2023"')
MT_D_M.query('District_name == "tiruchirappalli district"')
# Out:
#            States Years  Quater             District_name  Transaction_count  \
# 13768  Tamil Nadu  2023       1  tiruchirappalli district           10559157
# 13805  Tamil Nadu  2023       2  tiruchirappalli district           11012446
# 13842  Tamil Nadu  2023       3  tiruchirappalli district           12203674
# 13879  Tamil Nadu  2023       4  tiruchirappalli district           13546386
#
#        Transaction_amount
# 13768        1.931247e+10
# 13805        2.045545e+10
# 13842        2.174142e+10
# 13879        2.313066e+10

# %%
MT_D_M
# Out:
#            States Years  Quater             District_name  Transaction_count  \
# 13768  Tamil Nadu  2023       1  tiruchirappalli district           10559157
# 13769  Tamil Nadu  2023       1   ramanathapuram district            3161959
# 13770  Tamil Nadu  2023       1      krishnagiri district           27060721
# 13771  Tamil Nadu  2023       1        cuddalore district            8048998
# 13772  Tamil Nadu  2023       1     kancheepuram district           28434059
# ...           ...   ...     ...                       ...                ...
# 13911  Tamil Nadu  2023       4            theni district            6549554
# 13912  Tamil Nadu  2023       4          ranipet district            7743655
# 13913  Tamil Nadu  2023       4         namakkal district           10249122
# 13914  Tamil Nadu  2023       4          vellore district           13634855
# 13915  Tamil Nadu  2023       4       thiruvarur district            2801765
#
#        Transaction_amount
# ...

# %%
top_trans_df = pd.read_sql('top_trans', engine)

# %%
TT_D_M = top_trans_df.query('States == "Tamil Nadu" and Years == "2023" and Quater == 4')
#TT_D_M.query('District_name == "tiruchirappalli district"')
TT_D_M
# Out:
#           States Years  Quater Pincodes  Transaction_count  Transaction_amount
# 7357  Tamil Nadu  2023       4   635109            7538752        1.052224e+10
# 7358  Tamil Nadu  2023       4   635126            6313492        8.120200e+09
# 7359  Tamil Nadu  2023       4   602105            5916215        5.359677e+09
# 7360  Tamil Nadu  2023       4   641602            5901809        7.347320e+09
# 7361  Tamil Nadu  2023       4   600119            4994954        5.595168e+09
# 7362  Tamil Nadu  2023       4   600100            4942843        5.977497e+09
# 7363  Tamil Nadu  2023       4   600130            4003173        4.323193e+09
# 7364  Tamil Nadu  2023       4   600097            3861317        4.316032e+09
# 7365  Tamil Nadu  2023       4   600042            3652682        4.153672e+09
# 7366  Tamil Nadu  2023       4   641687            3551465        3.938941e+09

# %%
TT_D_M.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, 7357 to 7366
# Data columns (total 6 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   States              10 non-null     object
#  1   Years               10 non-null     object
#  2   Quater              10 non-null     int64
#  3   Pincodes            10 non-null     object
#  4   Transaction_count   10 non-null     int64
#  5   Transaction_amount  10 non-null     float64
# dtypes: float64(1), int64(2), object(3)
# memory usage: 560.0+ bytes

# %%
fig3 = px.bar(TT_D_M, x ='Transaction_count',
                                            y= 'Pincodes',
                                            )
                   
fig3.update_layout(xaxis_title='Transaction_count', yaxis_title='Pincodes')
fig3.show()

# %%
t = TT_D_M['Pincodes'].unique()
t
# Out:
# array(['635109', '635126', '602105', '641602', '600119', '600100',
#        '600130', '600097', '600042', '641687'], dtype=object)

# %%
type(t[1])
# Out:
# str

# %%
agg_users_df = pd.read_sql('agg_users', engine)
agg_users_df
# Out:
#                  States Years  Quater   Brands  Reg_user_count  Reg_percentage
# 0     Andaman & Nicobar  2018       1   Xiaomi            1665        0.247033
# 1     Andaman & Nicobar  2018       1  Samsung            1445        0.214392
# 2     Andaman & Nicobar  2018       1     Vivo             982        0.145697
# 3     Andaman & Nicobar  2018       1     Oppo             501        0.074332
# 4     Andaman & Nicobar  2018       1  OnePlus             332        0.049258
# ...                 ...   ...     ...      ...             ...             ...
# 6727        West Bengal  2022       1   Lenovo          330017        0.015056
# 6728        West Bengal  2022       1  Infinix          284678        0.012987
# 6729        West Bengal  2022       1     Asus          280347        0.012790
# 6730        West Bengal  2022       1    Apple          277752        0.012671
# 6731        West Bengal  2022       1   Others         2196334        0.100199
#
# [6732 rows x 6 columns]

# %%
agg_users_df.query(' Brands == "Xiaomi" and Years == "2022" ')
# Out:
#                                         States Years  Quater  Brands  \
# 177                          Andaman & Nicobar  2022       1  Xiaomi
# 363                             Andhra Pradesh  2022       1  Xiaomi
# 551                          Arunachal Pradesh  2022       1  Xiaomi
# 737                                      Assam  2022       1  Xiaomi
# 924                                      Bihar  2022       1  Xiaomi
# 1111                                Chandigarh  2022       1  Xiaomi
# 1299                              Chhattisgarh  2022       1  Xiaomi
# 1486  Dadra And Nagar Haveli And Daman And Diu  2022       1  Xiaomi
# 1672                                     Delhi  2022       1  Xiaomi
# 1859                                       Goa  2022       1  Xiaomi
# 2047                                   Gujarat  2022       1  Xiaomi
# 2233                                   Haryana  2022       1  Xiaomi
# 2420                          Himachal Pradesh  2022       1  Xiaomi
# ...

# %%
map_users_df = pd.read_sql('map_users', engine)

# %%
top_user_df = pd.read_sql('top_user', engine)
top_user_df
# Out:
#                  States Years  Quater Pincodes  Reg_users
# 0     Andaman & Nicobar  2018       1   744103       1608
# 1     Andaman & Nicobar  2018       1   744101       1108
# 2     Andaman & Nicobar  2018       1   744105       1075
# 3     Andaman & Nicobar  2018       1   744102       1006
# 4     Andaman & Nicobar  2018       1   744104        272
# ...                 ...   ...     ...      ...        ...
# 8563        West Bengal  2023       4   700015     126663
# 8564        West Bengal  2023       4   742304     123320
# 8565        West Bengal  2023       4   721101     123088
# 8566        West Bengal  2023       4   700150     119283
# 8567        West Bengal  2023       4   700091     118578
#
# [8568 rows x 5 columns]

# %%
TUS = top_user_df[top_user_df["Years"]=='2022']
TU_S_Map = TUS.groupby('States')['Reg_users'].sum()
TU_S_Map = TU_S_Map.to_frame().reset_index()
TU_S_Map
# Out:
#                                       States  Reg_users
# 0                          Andaman & Nicobar     286793
# 1                             Andhra Pradesh    7774517
# 2                          Arunachal Pradesh     822150
# 3                                      Assam    1754483
# 4                                      Bihar    7950988
# 5                                 Chandigarh    1785882
# 6                               Chhattisgarh    5446738
# 7   Dadra And Nagar Haveli And Daman And Diu    1848518
# 8                                      Delhi   16362563
# 9                                        Goa    1348115
# 10                                   Gujarat    9103129
# 11                                   Haryana   12544093
# 12                          Himachal Pradesh    2152928
# 13                           Jammu & Kashmir    1137125
# 14                                 Jharkhand    5034835
# 15                                 Karnataka   14982815
# ...
